# %%
import pandas as pd
import seaborn as  sns
import matplotlib.pyplot as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Prodigy InfoTech
df = pd.read_csv('customer_shopping_behavior.csv')

# %%
df.sample(5)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 529           530   32    Male         Shorts     Clothing
# 161           162   65    Male       Backpack  Accessories
# 1592         1593   56    Male          Shoes     Footwear
# 3898         3899   44  Female          Shoes     Footwear
# 3237         3238   61  Female        T-shirt     Clothing
#
#       Purchase Amount (USD)      Location Size   Color  Season  Review Rating  \
# 529                      84    California    M  Orange    Fall            3.7
# 161                      49  North Dakota    M   Olive    Fall            3.0
# 1592                     83          Iowa    M    Cyan  Summer            3.3
# 3898                     77     Minnesota    S   Brown  Summer            3.8
# 3237                     57       Vermont    M    Gray  Summer            2.8
#
#      Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# 529                  Yes       Standard              Yes             Yes
# 161                  Yes        Express              Yes             Yes
# 1592                  No  Free Shipping              Yes             Yes
# 3898                  No        Express               No              No
# 3237                  No        Express               No              No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 529                    6    Credit Card                Monthly
# 161                   29          Venmo            Fortnightly
# 1592                  10  Bank Transfer         Every 3 Months
# 3898                  24          Venmo                 Weekly
# 3237                   4           Cash                 Weekly

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True, color='blue')
plt.title('Distribution of Ages in Population')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', data=df, palette='viridis')
plt.title('Distribution of Genders')
plt.show()
